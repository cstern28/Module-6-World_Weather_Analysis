# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
np.random.seed(5)
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")


# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

    #except BaseException as e:
        #print(e)
        #print("City not found. Skipping...")
        #break
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | hofn
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | kindu
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | dingle
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | ahipara
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | tyup
# Processing Record 13 of Set 1 | gizo
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | san quintin
# Processing Record 19 of Set 1 | puerto madero
# Processing Record 20 of Set 1 | faya
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | zavitinsk
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | muli
# Processing Record 33 of Set 1 | santiago
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | tokur
# Processing Record 37 of Set 1 | pangody
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | broome
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | jijiga
# Processing Record 44 of Set 1 | thunder bay
# Processing Record 45 of Set 1 | curup
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | christchurch
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | mantua
# Processing Record 50 of Set 1 | pirovskoye
# Processing Record 1 of Set 2 | kavaratti
# Processing Record 2 of Set 2 | gwadar
# Processing Record 3 of Set 2 | nanortalik
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | pankovka
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | cabo san lucas
# Processing Record 10 of Set 2 | oranmore
# Processing Record 11 of Set 2 | vila velha
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | tyret pervaya
# Processing Record 14 of Set 2 | broken hill
# Processing Record 15 of Set 2 | badarwas
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | bara
# Processing Record 18 of Set 2 | norman wells
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | santa barbara
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | san cristobal
# Processing Record 25 of Set 2 | baykit
# Processing Record 26 of Set 2 | touros
# Processing Record 27 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 28 of Set 2 | khuzhir
# Processing Record 29 of Set 2 | coahuayana
# Processing Record 30 of Set 2 | nowy dwor gdanski
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | sena madureira
# Processing Record 33 of Set 2 | cookeville
# Processing Record 34 of Set 2 | port hedland
# Processing Record 35 of Set 2 | havoysund
# Processing Record 36 of Set 2 | chulumani
# Processing Record 37 of Set 2 | deputatskiy
# Processing Record 38 of Set 2 | matara
# Processing Record 39 of Set 2 | spring hill
# Processing Record 40 of Set 2 | nome
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 2 | bulgan
# Processing Record 44 of Set 2 | saint-pierre
# Processing Record 45 of Set 2 | crossville
# Processing Record 46 of Set 2 | verkhniy baskunchak
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | coihaique
# Processing Record 49 of Set 2 | manjacaze
# Processing Record 50 of Set 2 | grindavik
# Processing Record 1 of Set 3 | mitsamiouli
# Processing Record 2 of Set 3 | qaqortoq
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | coleraine
# Processing Record 6 of Set 3 | sukhobuzimskoye
# Processing Record 7 of Set 3 | sioux lookout
# Processing Record 8 of Set 3 | dakar
# Processing Record 9 of Set 3 | tuktoyaktuk
# Processing Record 10 of Set 3 | kavieng
# Processing Record 11 of Set 3 | sao joao da barra
# Processing Record 12 of Set 3 | sabha
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 3 | didwana
# Processing Record 17 of Set 3 | port alfred
# Processing Record 18 of Set 3 | burica
# City not found. Skipping...
# Processing Record 19 of Set 3 | clyde river
# Processing Record 20 of Set 3 | atar
# Processing Record 21 of Set 3 | namatanai
# Processing Record 22 of Set 3 | turan
# Processing Record 23 of Set 3 | san vicente
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | novyy svit
# Processing Record 26 of Set 3 | narsaq
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | huarmey
# Processing Record 29 of Set 3 | labuhan
# Processing Record 30 of Set 3 | vavoua
# Processing Record 31 of Set 3 | ancud
# Processing Record 32 of Set 3 | margate
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | port macquarie
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | nagapattinam
# Processing Record 38 of Set 3 | mirpur khas
# Processing Record 39 of Set 3 | kodiak
# Processing Record 40 of Set 3 | lompoc
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | alofi
# Processing Record 43 of Set 3 | matagami
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | ilhabela
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | skibbereen
# Processing Record 48 of Set 3 | cockburn town
# Processing Record 49 of Set 3 | council bluffs
# Processing Record 50 of Set 3 | sojat
# Processing Record 1 of Set 4 | kieta
# Processing Record 2 of Set 4 | xingyi
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 4 | ilulissat
# Processing Record 5 of Set 4 | chalon-sur-saone
# Processing Record 6 of Set 4 | yantal
# Processing Record 7 of Set 4 | cidreira
# Processing Record 8 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | churapcha
# Processing Record 11 of Set 4 | hovd
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | wangqing
# Processing Record 14 of Set 4 | flinders
# Processing Record 15 of Set 4 | ketchikan
# Processing Record 16 of Set 4 | kharitonovo
# Processing Record 17 of Set 4 | filadelfia
# Processing Record 18 of Set 4 | folldal
# Processing Record 19 of Set 4 | matameye
# City not found. Skipping...
# Processing Record 20 of Set 4 | nouadhibou
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 23 of Set 4 | rongcheng
# Processing Record 24 of Set 4 | vardo
# Processing Record 25 of Set 4 | pemba
# Processing Record 26 of Set 4 | chisec
# Processing Record 27 of Set 4 | panama city
# Processing Record 28 of Set 4 | meulaboh
# Processing Record 29 of Set 4 | shakhtinsk
# Processing Record 30 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 4 | kahului
# Processing Record 32 of Set 4 | calama
# Processing Record 33 of Set 4 | coquimbo
# Processing Record 34 of Set 4 | port moresby
# Processing Record 35 of Set 4 | kukmor
# Processing Record 36 of Set 4 | egvekinot
# Processing Record 37 of Set 4 | maymanak
# City not found. Skipping...
# Processing Record 38 of Set 4 | vestmannaeyjar
# Processing Record 39 of Set 4 | honningsvag
# Processing Record 40 of Set 4 | boyolangu
# Processing Record 41 of Set 4 | sola
# Processing Record 42 of Set 4 | doembang nangbuat
# Processing Record 43 of Set 4 | tocopilla
# Processing Record 44 of Set 4 | souillac
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | fairbanks
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | banda aceh
# Processing Record 49 of Set 4 | sao felix do xingu
# Processing Record 50 of Set 4 | yumen
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 5 | de-kastri
# Processing Record 4 of Set 5 | nikolskoye
# Processing Record 5 of Set 5 | pacific grove
# Processing Record 6 of Set 5 | plouzane
# Processing Record 7 of Set 5 | tual
# Processing Record 8 of Set 5 | srednekolymsk
# Processing Record 9 of Set 5 | kirovskiy
# Processing Record 10 of Set 5 | new port richey
# Processing Record 11 of Set 5 | poum
# Processing Record 12 of Set 5 | yakima
# Processing Record 13 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 5 | yeppoon
# Processing Record 15 of Set 5 | san ramon de la nueva oran
# Processing Record 16 of Set 5 | matay
# Processing Record 17 of Set 5 | mandurah
# Processing Record 18 of Set 5 | kapit
# Processing Record 19 of Set 5 | katsuura
# Processing Record 20 of Set 5 | luderitz
# Processing Record 21 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 5 | klaksvik
# Processing Record 23 of Set 5 | suclayin
# Processing Record 24 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 25 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 26 of Set 5 | yellowknife
# Processing Record 27 of Set 5 | pangnirtung
# Processing Record 28 of Set 5 | richards bay
# Processing Record 29 of Set 5 | ginda
# Processing Record 30 of Set 5 | palmer
# Processing Record 31 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 5 | hasaki
# Processing Record 33 of Set 5 | fort saint james
# Processing Record 34 of Set 5 | dunedin
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | hithadhoo
# Processing Record 37 of Set 5 | yichang
# Processing Record 38 of Set 5 | lakselv
# Processing Record 39 of Set 5 | roma
# Processing Record 40 of Set 5 | hammerfest
# Processing Record 41 of Set 5 | kisoro
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | voskresenskoye
# Processing Record 44 of Set 5 | noyabrsk
# Processing Record 45 of Set 5 | pimentel
# Processing Record 46 of Set 5 | svetlogorsk
# Processing Record 47 of Set 5 | saldanha
# Processing Record 48 of Set 5 | tura
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | ballina
# Processing Record 1 of Set 6 | mponela
# Processing Record 2 of Set 6 | rocha
# Processing Record 3 of Set 6 | talaya
# Processing Record 4 of Set 6 | pearl river
# Processing Record 5 of Set 6 | burnie
# Processing Record 6 of Set 6 | boa vista
# Processing Record 7 of Set 6 | fergus falls
# Processing Record 8 of Set 6 | mashivka
# Processing Record 9 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 6 | beringovskiy
# Processing Record 12 of Set 6 | riyadh
# Processing Record 13 of Set 6 | trairi
# Processing Record 14 of Set 6 | bystrzyca klodzka
# Processing Record 15 of Set 6 | mackay
# Processing Record 16 of Set 6 | zambezi
# Processing Record 17 of Set 6 | olga
# Processing Record 18 of Set 6 | sarangani
# Processing Record 19 of Set 6 | jining
# Processing Record 20 of Set 6 | nabire
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | berdyaush
# Processing Record 23 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 6 | superior
# Processing Record 25 of Set 6 | rancho palos verdes
# Processing Record 26 of Set 6 | tabas
# Processing Record 27 of Set 6 | garden city
# Processing Record 28 of Set 6 | ulaangom
# Processing Record 29 of Set 6 | iqaluit
# Processing Record 30 of Set 6 | la rochelle
# Processing Record 31 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 6 | henties bay
# Processing Record 33 of Set 6 | saint-augustin
# Processing Record 34 of Set 6 | pozo colorado
# Processing Record 35 of Set 6 | chifeng
# Processing Record 36 of Set 6 | nayudupeta
# Processing Record 37 of Set 6 | grand forks
# Processing Record 38 of Set 6 | kondapalle
# Processing Record 39 of Set 6 | navabad
# City not found. Skipping...
# Processing Record 40 of Set 6 | kutum
# Processing Record 41 of Set 6 | leningradskiy
# Processing Record 42 of Set 6 | iquitos
# Processing Record 43 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 6 | enumclaw
# Processing Record 45 of Set 6 | cayenne
# Processing Record 46 of Set 6 | sampit
# Processing Record 47 of Set 6 | half moon bay
# Processing Record 48 of Set 6 | graaff-reinet
# Processing Record 49 of Set 6 | chore
# City not found. Skipping...
# Processing Record 50 of Set 6 | kudymkar
# Processing Record 1 of Set 7 | talara
# Processing Record 2 of Set 7 | zhigansk
# Processing Record 3 of Set 7 | lagoa
# Processing Record 4 of Set 7 | karpathos
# Processing Record 5 of Set 7 | deep river
# Processing Record 6 of Set 7 | samarai
# Processing Record 7 of Set 7 | narodychi
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | tessalit
# Processing Record 10 of Set 7 | ceuta
# Processing Record 11 of Set 7 | mataram
# Processing Record 12 of Set 7 | muros
# Processing Record 13 of Set 7 | kalengwa
# Processing Record 14 of Set 7 | maragogi
# Processing Record 15 of Set 7 | chicama
# Processing Record 16 of Set 7 | talnakh
# Processing Record 17 of Set 7 | asfi
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | sharan
# Processing Record 20 of Set 7 | tamandare
# Processing Record 21 of Set 7 | shenjiamen
# Processing Record 22 of Set 7 | linden
# Processing Record 23 of Set 7 | mount isa
# Processing Record 24 of Set 7 | sibolga
# Processing Record 25 of Set 7 | la paz
# Processing Record 26 of Set 7 | bosaso
# Processing Record 27 of Set 7 | bilibino
# Processing Record 28 of Set 7 | parati
# Processing Record 29 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 7 | vila franca do campo
# Processing Record 31 of Set 7 | sabalgarh
# Processing Record 32 of Set 7 | tilichiki
# Processing Record 33 of Set 7 | murchison
# Processing Record 34 of Set 7 | tabou
# Processing Record 35 of Set 7 | olafsvik
# Processing Record 36 of Set 7 | itarema
# Processing Record 37 of Set 7 | brae
# Processing Record 38 of Set 7 | obo
# Processing Record 39 of Set 7 | noumea
# Processing Record 40 of Set 7 | austin
# Processing Record 41 of Set 7 | muisne
# Processing Record 42 of Set 7 | ojinaga
# Processing Record 43 of Set 7 | pavlivka
# Processing Record 44 of Set 7 | baoding
# Processing Record 45 of Set 7 | asyut
# Processing Record 46 of Set 7 | nara
# Processing Record 47 of Set 7 | jacqueville
# Processing Record 48 of Set 7 | arteaga
# Processing Record 49 of Set 7 | bathsheba
# Processing Record 50 of Set 7 | pangoa
# Processing Record 1 of Set 8 | meilu
# City not found. Skipping...
# Processing Record 2 of Set 8 | kudahuvadhoo
# Processing Record 3 of Set 8 | linhares
# Processing Record 4 of Set 8 | avera
# Processing Record 5 of Set 8 | longyearbyen
# Processing Record 6 of Set 8 | angul
# Processing Record 7 of Set 8 | odweyne
# Processing Record 8 of Set 8 | bilma
# Processing Record 9 of Set 8 | picui
# Processing Record 10 of Set 8 | nioro
# Processing Record 11 of Set 8 | brunsbuttel
# Processing Record 12 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 8 | westport
# Processing Record 14 of Set 8 | tuy hoa
# Processing Record 15 of Set 8 | amga
# Processing Record 16 of Set 8 | lake city
# Processing Record 17 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 8 | sumenep
# Processing Record 19 of Set 8 | nhulunbuy
# Processing Record 20 of Set 8 | tena
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | nosy varika
# Processing Record 23 of Set 8 | bengkulu
# Processing Record 24 of Set 8 | bonito
# Processing Record 25 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 8 | hambantota
# Processing Record 27 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 8 | venice
# Processing Record 29 of Set 8 | qinnan
# Processing Record 30 of Set 8 | saint-paul
# Processing Record 31 of Set 8 | saint george
# Processing Record 32 of Set 8 | teacapan
# Processing Record 33 of Set 8 | thompson
# Processing Record 34 of Set 8 | greytown
# Processing Record 35 of Set 8 | seoul
# Processing Record 36 of Set 8 | butia
# Processing Record 37 of Set 8 | sitka
# Processing Record 38 of Set 8 | loiza
# Processing Record 39 of Set 8 | vaitape
# Processing Record 40 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 42 of Set 8 | nicoya
# Processing Record 43 of Set 8 | qaanaaq
# Processing Record 44 of Set 8 | chowchilla
# Processing Record 45 of Set 8 | kisangani
# Processing Record 46 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 8 | erzin
# Processing Record 48 of Set 8 | taganak
# Processing Record 49 of Set 8 | guerrero negro
# Processing Record 50 of Set 8 | tupik
# Processing Record 1 of Set 9 | montepuez
# Processing Record 2 of Set 9 | menongue
# Processing Record 3 of Set 9 | matamoros
# Processing Record 4 of Set 9 | show low
# Processing Record 5 of Set 9 | kangaatsiaq
# Processing Record 6 of Set 9 | san policarpo
# Processing Record 7 of Set 9 | balad
# Processing Record 8 of Set 9 | aksarka
# Processing Record 9 of Set 9 | phan thiet
# Processing Record 10 of Set 9 | yining
# Processing Record 11 of Set 9 | srandakan
# Processing Record 12 of Set 9 | rome
# Processing Record 13 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 14 of Set 9 | thinadhoo
# Processing Record 15 of Set 9 | bonavista
# Processing Record 16 of Set 9 | arlit
# Processing Record 17 of Set 9 | bac lieu
# Processing Record 18 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 9 | kitimat
# Processing Record 20 of Set 9 | salalah
# Processing Record 21 of Set 9 | hagere hiywet
# Processing Record 22 of Set 9 | puerto escondido
# Processing Record 23 of Set 9 | razole
# Processing Record 24 of Set 9 | acarau
# Processing Record 25 of Set 9 | mozarlandia
# Processing Record 26 of Set 9 | eureka
# Processing Record 27 of Set 9 | shu
# Processing Record 28 of Set 9 | fayaoue
# Processing Record 29 of Set 9 | lubao
# Processing Record 30 of Set 9 | praia da vitoria
# Processing Record 31 of Set 9 | garcia
# Processing Record 32 of Set 9 | awka
# Processing Record 33 of Set 9 | champerico
# Processing Record 34 of Set 9 | carmarthen
# Processing Record 35 of Set 9 | katakwi
# Processing Record 36 of Set 9 | kaili
# Processing Record 37 of Set 9 | codrington
# Processing Record 38 of Set 9 | pochutla
# Processing Record 39 of Set 9 | alice springs
# Processing Record 40 of Set 9 | lancaster
# Processing Record 41 of Set 9 | elblag
# Processing Record 42 of Set 9 | kulhudhuffushi
# Processing Record 43 of Set 9 | nouakchott
# Processing Record 44 of Set 9 | caravelas
# Processing Record 45 of Set 9 | sladkovo
# Processing Record 46 of Set 9 | sao filipe
# Processing Record 47 of Set 9 | jieshi
# Processing Record 48 of Set 9 | gamboma
# Processing Record 49 of Set 9 | mangaluru
# Processing Record 50 of Set 9 | elko
# Processing Record 1 of Set 10 | wegrow
# Processing Record 2 of Set 10 | fortuna
# Processing Record 3 of Set 10 | bandar penggaram
# City not found. Skipping...
# Processing Record 4 of Set 10 | tuatapere
# Processing Record 5 of Set 10 | syedove
# Processing Record 6 of Set 10 | ambilobe
# Processing Record 7 of Set 10 | peterhead
# Processing Record 8 of Set 10 | sfantu gheorghe
# Processing Record 9 of Set 10 | warrington
# Processing Record 10 of Set 10 | maldonado
# Processing Record 11 of Set 10 | dodoma
# Processing Record 12 of Set 10 | yamethin
# Processing Record 13 of Set 10 | shitanjing
# Processing Record 14 of Set 10 | takab
# Processing Record 15 of Set 10 | concordia
# Processing Record 16 of Set 10 | salamiyah
# Processing Record 17 of Set 10 | beloha
# Processing Record 18 of Set 10 | angoche
# Processing Record 19 of Set 10 | grand-lahou
# Processing Record 20 of Set 10 | pacifica
# Processing Record 21 of Set 10 | belyy yar
# Processing Record 22 of Set 10 | asekeyevo
# Processing Record 23 of Set 10 | erenhot
# Processing Record 24 of Set 10 | maceio
# Processing Record 25 of Set 10 | pfarrkirchen
# Processing Record 26 of Set 10 | draguignan
# Processing Record 27 of Set 10 | kangundo
# Processing Record 28 of Set 10 | camacha
# Processing Record 29 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 30 of Set 10 | kalaleh
# Processing Record 31 of Set 10 | luocheng
# Processing Record 32 of Set 10 | korla
# Processing Record 33 of Set 10 | okhotsk
# Processing Record 34 of Set 10 | havre-saint-pierre
# Processing Record 35 of Set 10 | vila
# Processing Record 36 of Set 10 | praya
# Processing Record 37 of Set 10 | karratha
# Processing Record 38 of Set 10 | goderich
# Processing Record 39 of Set 10 | pafos
# Processing Record 40 of Set 10 | trelew
# Processing Record 41 of Set 10 | port blair
# Processing Record 42 of Set 10 | savonlinna
# Processing Record 43 of Set 10 | suleja
# Processing Record 44 of Set 10 | ostrovnoy
# Processing Record 45 of Set 10 | sambava
# Processing Record 46 of Set 10 | rantepao
# Processing Record 47 of Set 10 | dolores
# Processing Record 48 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 10 | majene
# Processing Record 50 of Set 10 | bud
# Processing Record 1 of Set 11 | khani
# Processing Record 2 of Set 11 | hobyo
# Processing Record 3 of Set 11 | puerto del rosario
# Processing Record 4 of Set 11 | magnitogorsk
# Processing Record 5 of Set 11 | winnemucca
# Processing Record 6 of Set 11 | dzhebariki-khaya
# Processing Record 7 of Set 11 | kony
# Processing Record 8 of Set 11 | kismayo
# Processing Record 9 of Set 11 | sistranda
# Processing Record 10 of Set 11 | baracoa
# Processing Record 11 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 11 | valdivia
# Processing Record 13 of Set 11 | port lincoln
# Processing Record 14 of Set 11 | boende
# Processing Record 15 of Set 11 | sur
# Processing Record 16 of Set 11 | tengushevo
# Processing Record 17 of Set 11 | chernyshevskiy
# Processing Record 18 of Set 11 | jinka
# Processing Record 19 of Set 11 | wattegama
# Processing Record 20 of Set 11 | aberystwyth
# Processing Record 21 of Set 11 | sao geraldo do araguaia
# Processing Record 22 of Set 11 | los llanos de aridane
# Processing Record 23 of Set 11 | ambatondrazaka
# Processing Record 24 of Set 11 | little current
# Processing Record 25 of Set 11 | manicore
# Processing Record 26 of Set 11 | berlevag
# Processing Record 27 of Set 11 | arman
# Processing Record 28 of Set 11 | umea
# Processing Record 29 of Set 11 | pangkalanbuun
# Processing Record 30 of Set 11 | acurenam
# Processing Record 31 of Set 11 | sikasso
# Processing Record 32 of Set 11 | kodinsk
# Processing Record 33 of Set 11 | cherepovets
# Processing Record 34 of Set 11 | birao
# Processing Record 35 of Set 11 | luanda
# Processing Record 36 of Set 11 | obuasi
# Processing Record 37 of Set 11 | ashiya
# Processing Record 38 of Set 11 | tarauaca
# Processing Record 39 of Set 11 | sinnamary
# Processing Record 40 of Set 11 | nizhnevartovsk
# Processing Record 41 of Set 11 | lake charles
# Processing Record 42 of Set 11 | chapleau
# Processing Record 43 of Set 11 | ranong
# Processing Record 44 of Set 11 | karatuzskoye
# Processing Record 45 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 11 | porto novo
# Processing Record 47 of Set 11 | baiyin
# Processing Record 48 of Set 11 | kaniama
# Processing Record 49 of Set 11 | tabory
# Processing Record 50 of Set 11 | jalu
# Processing Record 1 of Set 12 | lasa
# Processing Record 2 of Set 12 | florence
# Processing Record 3 of Set 12 | takoradi
# Processing Record 4 of Set 12 | manaure
# Processing Record 5 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 12 | paamiut
# Processing Record 7 of Set 12 | grand gaube
# Processing Record 8 of Set 12 | naze
# Processing Record 9 of Set 12 | kandrian
# Processing Record 10 of Set 12 | constitucion
# Processing Record 11 of Set 12 | isangel
# Processing Record 12 of Set 12 | qasigiannguit
# Processing Record 13 of Set 12 | barreirinha
# Processing Record 14 of Set 12 | rafraf
# Processing Record 15 of Set 12 | mezen
# Processing Record 16 of Set 12 | teya
# Processing Record 17 of Set 12 | kabul
# Processing Record 18 of Set 12 | jos
# Processing Record 19 of Set 12 | zonguldak
# Processing Record 20 of Set 12 | resistencia
# Processing Record 21 of Set 12 | dali
# Processing Record 22 of Set 12 | basoda
# Processing Record 23 of Set 12 | gat
# Processing Record 24 of Set 12 | nibbar
# Processing Record 25 of Set 12 | liku
# Processing Record 26 of Set 12 | bambanglipuro
# Processing Record 27 of Set 12 | manyana
# Processing Record 28 of Set 12 | arivonimamo
# Processing Record 29 of Set 12 | gerede
# Processing Record 30 of Set 12 | vanavara
# Processing Record 31 of Set 12 | mogadishu
# Processing Record 32 of Set 12 | lubu
# Processing Record 33 of Set 12 | ponta delgada
# Processing Record 34 of Set 12 | sertanopolis
# Processing Record 35 of Set 12 | daru
# Processing Record 36 of Set 12 | bonthe
# Processing Record 37 of Set 12 | adrar
# Processing Record 38 of Set 12 | ust-barguzin
# Processing Record 39 of Set 12 | amazar
# Processing Record 40 of Set 12 | canutama
# Processing Record 41 of Set 12 | urucara
# Processing Record 42 of Set 12 | cefalu
# Processing Record 43 of Set 12 | yulara
# Processing Record 44 of Set 12 | progreso
# Processing Record 45 of Set 12 | acapulco
# Processing Record 46 of Set 12 | anaconda
# Processing Record 47 of Set 12 | gouyave
# Processing Record 48 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 49 of Set 12 | nemuro
# Processing Record 50 of Set 12 | wanning
# Processing Record 1 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 2 of Set 13 | rawson
# Processing Record 3 of Set 13 | nanakuli
# Processing Record 4 of Set 13 | foldeak
# Processing Record 5 of Set 13 | tazovskiy
# Processing Record 6 of Set 13 | tabuk
# Processing Record 7 of Set 13 | barguzin
# Processing Record 8 of Set 13 | imbituba
# Processing Record 9 of Set 13 | anadyr
# Processing Record 10 of Set 13 | bagan
# Processing Record 11 of Set 13 | roquetas de mar
# Processing Record 12 of Set 13 | blind river
# Processing Record 13 of Set 13 | dicabisagan
# Processing Record 14 of Set 13 | tongzi
# Processing Record 15 of Set 13 | sudak
# Processing Record 16 of Set 13 | merauke
# Processing Record 17 of Set 13 | kastamonu
# Processing Record 18 of Set 13 | namibe
# Processing Record 19 of Set 13 | laguna
# Processing Record 20 of Set 13 | bushehr
# Processing Record 21 of Set 13 | ajdabiya
# Processing Record 22 of Set 13 | komsomolskiy
# Processing Record 23 of Set 13 | mabaruma
# Processing Record 24 of Set 13 | capoterra
# Processing Record 25 of Set 13 | terra rica
# Processing Record 26 of Set 13 | maniitsoq
# Processing Record 27 of Set 13 | joshimath
# Processing Record 28 of Set 13 | fare
# Processing Record 29 of Set 13 | pantai remis
# Processing Record 30 of Set 13 | campeche
# Processing Record 31 of Set 13 | lethem
# Processing Record 32 of Set 13 | ulladulla
# Processing Record 33 of Set 13 | new ulm
# Processing Record 34 of Set 13 | las colinas
# Processing Record 35 of Set 13 | galle
# Processing Record 36 of Set 13 | moyale
# Processing Record 37 of Set 13 | barra
# Processing Record 38 of Set 13 | tooele
# Processing Record 39 of Set 13 | brest
# Processing Record 40 of Set 13 | ishigaki
# Processing Record 41 of Set 13 | ous
# Processing Record 42 of Set 13 | limbang
# Processing Record 43 of Set 13 | dubbo
# Processing Record 44 of Set 13 | merrill
# Processing Record 45 of Set 13 | nenjiang
# Processing Record 46 of Set 13 | kawalu
# Processing Record 47 of Set 13 | solnechnyy
# Processing Record 48 of Set 13 | stromness
# Processing Record 49 of Set 13 | turbat
# Processing Record 50 of Set 13 | bedford
# Processing Record 1 of Set 14 | dagua
# Processing Record 2 of Set 14 | banepa
# Processing Record 3 of Set 14 | west bay
# Processing Record 4 of Set 14 | hay river
# Processing Record 5 of Set 14 | tungor
# Processing Record 6 of Set 14 | necochea
# Processing Record 7 of Set 14 | morristown
# Processing Record 8 of Set 14 | vanimo
# Processing Record 9 of Set 14 | tevaitoa
# Processing Record 10 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 11 of Set 14 | college
# Processing Record 12 of Set 14 | tatawin
# Processing Record 13 of Set 14 | kingman
# Processing Record 14 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 14 | tautira
# Processing Record 16 of Set 14 | laramie
# Processing Record 17 of Set 14 | machali
# Processing Record 18 of Set 14 | zyryanka
# Processing Record 19 of Set 14 | cairns
# Processing Record 20 of Set 14 | shiyan
# Processing Record 21 of Set 14 | emba
# Processing Record 22 of Set 14 | dawei
# Processing Record 23 of Set 14 | volkhov
# Processing Record 24 of Set 14 | tsiroanomandidy
# Processing Record 25 of Set 14 | ampanihy
# Processing Record 26 of Set 14 | shingu
# Processing Record 27 of Set 14 | ravar
# Processing Record 28 of Set 14 | warrnambool
# Processing Record 29 of Set 14 | bahia blanca
# Processing Record 30 of Set 14 | monterey
# Processing Record 31 of Set 14 | youkounkoun
# Processing Record 32 of Set 14 | omboue
# Processing Record 33 of Set 14 | finspang
# Processing Record 34 of Set 14 | urengoy
# Processing Record 35 of Set 14 | la ronge
# Processing Record 36 of Set 14 | general pico
# Processing Record 37 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 38 of Set 14 | chara
# Processing Record 39 of Set 14 | bolobo
# Processing Record 40 of Set 14 | wurzen
# Processing Record 41 of Set 14 | keti bandar
# Processing Record 42 of Set 14 | denpasar
# Processing Record 43 of Set 14 | aktau
# Processing Record 44 of Set 14 | baglung
# Processing Record 45 of Set 14 | skibotn
# Processing Record 46 of Set 14 | alamor
# Processing Record 47 of Set 14 | aklavik
# Processing Record 48 of Set 14 | kaeo
# Processing Record 49 of Set 14 | richmond
# Processing Record 50 of Set 14 | qeshm
# Processing Record 1 of Set 15 | igarka
# Processing Record 2 of Set 15 | saulkrasti
# Processing Record 3 of Set 15 | storsteinnes
# Processing Record 4 of Set 15 | umm lajj
# Processing Record 5 of Set 15 | hirara
# Processing Record 6 of Set 15 | mahibadhoo
# Processing Record 7 of Set 15 | sitangkai
# Processing Record 8 of Set 15 | bagdarin
# Processing Record 9 of Set 15 | faanui
# Processing Record 10 of Set 15 | tosya
# Processing Record 11 of Set 15 | kristianstad
# Processing Record 12 of Set 15 | tinyahuarco
# Processing Record 13 of Set 15 | andra
# Processing Record 14 of Set 15 | pilao arcado
# City not found. Skipping...
# Processing Record 15 of Set 15 | botucatu
# Processing Record 16 of Set 15 | orocue
# Processing Record 17 of Set 15 | seymchan
# Processing Record 18 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 19 of Set 15 | kilmez
# City not found. Skipping...
# Processing Record 20 of Set 15 | vestmanna
# Processing Record 21 of Set 15 | kroya
# Processing Record 22 of Set 15 | mount gambier
# Processing Record 23 of Set 15 | port-cartier
# Processing Record 24 of Set 15 | poplar bluff
# Processing Record 25 of Set 15 | buta
# Processing Record 26 of Set 15 | shchors
# Processing Record 27 of Set 15 | berbera
# Processing Record 28 of Set 15 | abu dhabi
# Processing Record 29 of Set 15 | balvi
# Processing Record 30 of Set 15 | labrea
# Processing Record 31 of Set 15 | antalaha
# Processing Record 32 of Set 15 | gunnedah
# Processing Record 33 of Set 15 | diego de almagro
# Processing Record 34 of Set 15 | rantauprapat
# Processing Record 35 of Set 15 | karangasem
# Processing Record 36 of Set 15 | inta
# Processing Record 37 of Set 15 | mao
# Processing Record 38 of Set 15 | mucuri
# Processing Record 39 of Set 15 | saucillo
# Processing Record 40 of Set 15 | diffa
# Processing Record 41 of Set 15 | nalut
# Processing Record 42 of Set 15 | carauari
# Processing Record 43 of Set 15 | axim
# Processing Record 44 of Set 15 | nathdwara
# Processing Record 45 of Set 15 | batken
# Processing Record 46 of Set 15 | oxelosund
# Processing Record 47 of Set 15 | loralai
# Processing Record 48 of Set 15 | katangli
# Processing Record 49 of Set 15 | saint-joseph
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton -33.6500  115.3333     61.23        70          93
# 1            Hofn  64.2539  -15.2082     53.62        54          75
# 2     East London -33.0153   27.9116     58.14        94           0
# 3           Kindu  -2.9500   25.9500     71.64        95         100
# 4           Kapaa  22.0752 -159.3190     77.11        85          56
# 5          Dingle  10.9995  122.6711     77.43        89          97
# 6          Atuona  -9.8000 -139.0333     77.38        82          24
# 7         Ahipara -35.1667  173.1667     59.11        76          98
# 8  Port Elizabeth -33.9180   25.5701     58.10        74          84
# 9         Ushuaia -54.8000  -68.3000     38.86        87           0
#
#    Wind Speed Weather Description Country                 Date
# 0       25.70          light rain      AU  2022-05-22 17:50:17
# 1       14.97       broken clouds      IS  2022-05-22 17:59:43
# 2        4.61           clear sky      ZA  2022-05-22 17:59:44
# 3        2.04          light rain      CD  2022-05-22 18:00:12
# 4        1.99       broken clouds      US  2022-05-22 17:57:33
# 5        4.27     overcast clouds      PH  2022-05-22 18:00:13
# 6       17.11          light rain      PF  2022-05-22 18:00:12
# 7       10.85     overcast clouds      NZ  2022-05-22 18:00:14
# 8        1.52       broken clouds      ZA  2022-05-22 18:00:15
# 9        4.61           clear sky      AR  2022-05-22 17:58:39

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity","Cloudiness", "Wind Speed", "Weather Description"]
city_newcol_df = city_data_df[new_column_order]
city_newcol_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Busselton      AU -33.6500  115.3333     61.23        70          93
# 1         Hofn      IS  64.2539  -15.2082     53.62        54          75
# 2  East London      ZA -33.0153   27.9116     58.14        94           0
# 3        Kindu      CD  -2.9500   25.9500     71.64        95         100
# 4        Kapaa      US  22.0752 -159.3190     77.11        85          56
#
#    Wind Speed Weather Description
# 0       25.70          light rain
# 1       14.97       broken clouds
# 2        4.61           clear sky
# 3        2.04          light rain
# 4        1.99       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Resources/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_newcol_df.to_csv(output_data_file, index_label="City_ID")
